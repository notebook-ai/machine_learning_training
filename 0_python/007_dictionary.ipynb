# %%
"""
a python dictionary is on such data structure tha can store data in the from key-value
"""

# %%
empty_dic = {}
empty_dic
# Out:
# {}

# %%
student_score = {
    "Math" : 19,
    "Chemistry": 16.75,
    "Physics": 18
}
print(student_score)
print(student_score["Math"])
# Out:
# {'Math': 19, 'Chemistry': 16.75, 'Physics': 18}
# 19

# %%
learning_ai_roadmap = {
    1: "Math",
    2: "Machin leaning",
    3: "SNN", # shallow neural network
    4: "DNN" # deep neural network
}
print(learning_ai_roadmap)
print(learning_ai_roadmap[1])
# Out:
# {1: 'Math', 2: 'Machin leaning', 3: 'SNN', 4: 'DNN'}
# Math

# %%
complex_dic1 = {
    "frut": "Mango",
    1: [1,2,3,4]
}
print(complex_dic1)
# Out:
# {'frut': 'Mango', 1: [1, 2, 3, 4]}

# %%
learning_ml_roadmap = dict({
    1: "python",
    2: "math",
    3: {
        1: "Supervised Learning",
        2: "Unsupervised Learning",
        3: ""
        }
})
print(learning_ml_roadmap)
