# %%
my_information = {
    "firstname": "john",
    "lastname": "bovary",
    "age" : 30
}

msg = f"""
Hello
my fullname is {my_information['firstname']} {my_information['lastname']},
I'm {my_information['age']} years old.
"""
msg
# Out:
# "\nHello\nmy fullname is john bovary,\nI'm 30 years old.\n"
