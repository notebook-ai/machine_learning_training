# %%
class COURSE:
    course_name = ""
    members = 0

obj_course = COURSE()
obj_course.course_name = "Machine Learning"
obj_course.members = 10
obj_course.check = 4152 # ! Important
print(obj_course.course_name ,":", obj_course.members)
print(obj_course.check)
# Out:
# Machine Learning : 10
# 4152

# %%
class COURSE_02:
    pass

# %%
two = COURSE_02()
two.Cname = "test."
print(two.Cname)
# Out:
# test.

# %%
class Person:
    def __init__(self, name, family):
        self.name = name
        self.family = family
        
    def say_hello(self):
        return (f"you'r fullname is {self.name} {self.family}")

per_name = input("you'r name:")
per_family = input("you'r family:")
obj_person = Person(per_name, per_family)
print(obj_person.name, obj_person.family)
print(obj_person.say_hello())
# Out:
# john wick
# you'r fullname is john wick

# %%
class Calculater:
   
   def __init__(self, operation, x, y):
        self.operation = operation
        self.x = x
        self.y = y
        
   def calc_function(self):
    if self.operation =="+":
        return self.x + self.y
    elif self.operation =="-":
        return self.x - self.y
    elif self.operation == "*":
        return self.x * self.y
    elif self.operation == "/":
        if self.y!=0:
            return self.x / self.y
        else:
            return "Cannot divided by zero"
    elif self.operation == "%":
        return self.x % self.y
    else:
        return "Invalid operation"

obj_calc = Calculater("+", 8,9)
result = obj_calc.calc_function()
print(result)
# Out:
# 17

# %%
class TestClass:
    def say_something(self, name):
        res = f"Hello, {name}"
        return res

obj_test = TestClass()
print(obj_test.say_something("Eric"))
# Out:
# Hello, Eric

# %%
class Car:
    def __init__(self, company, model, year):
        self.company = company
        self.model = model
        self.year = year
        
    def car_info(self):
        return f"you'r car info: {self.company}, {self.model}, {self.year}"
    
obj_car = Car("Toyota", "Camery", 2024)
print(obj_car.car_info())
# Out:
# you'r car info: Toyota, Camery, 2024

# %%
# study about private value
class Student:
    def __init__(self, funllname, age):
        self.funllname = funllname
        self.__age = age #private variable
    
    def get_age(self):
        return self.__age
    
# Creating an object
obj_student = Student("bob ros", 31)
print(f"you'r info is {obj_student.funllname} {obj_student.__age}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 12
#      10 # Creating an object
#      11 obj_student = Student("bob ros", 31)
# ---> 12 print(f"you'r info is {obj_student.funllname} {obj_student.__age}")
#
# AttributeError: 'Student' object has no attribute '__age'

# %%
print(obj_student.get_age())
print(f"you'r info is {obj_student.funllname} {obj_student.get_age()}")
# Out:
# 31
# you'r info is bob ros 31

# %%
# Encapsulation
class BackAccount:
    def __init__(self, account_number, balance):
        self.__account_number = account_number # private variable
        self.__balance = balance # private variable

    def get_balance(self):
        return self.__balance
    
    def deposit(self, amount):
        if amount > 0:
            self.__balance +=amount

account = BackAccount("415263", 1000)
print(account.get_balance())
account.deposit(500)
print(account.get_balance())
# Out:
# 1000
# 1500

# %%
# Inheritance class in python
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        pass

class Dog(Animal):
    def color(self):
        return f"{self.name} is gray"
    
dog = Dog("Buddy")
print(dog.color())
# Out:
# Buddy is gray

# %%
# Inheritance
class Parent:
    def func1(self):
        print("this is function one into Parent class")
class Child(Parent):
    def func2(self):
        print(" this is function 2 into Child class")

ob = Child()
ob.func1()
ob.func2()
# Out:
# this is function one into Parent class
#  this is function 2 into Child class

# %%
# code
class Person:

	# Constructor
	def __init__(self, name, id):
		self.name = name
		self.id = id

	# To check if this person is an employee
	def Display(self):
		print(self.name, self.id)
	

class Emp(Person):
	
	def __init__(self, name, id):
		self.name_ = name

	def Print(self):
		print("Emp class called")

Emp_details = Emp("David", 103)

# calling parent class function
Emp_details.name_, Emp_details.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 25
#      22 Emp_details = Emp("David", 103)
#      24 # calling parent class function
# ---> 25 Emp_details.name_, Emp_details.name
#
# AttributeError: 'Emp' object has no attribute 'name'
