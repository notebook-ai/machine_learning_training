# %%
# calculate the sum of all even number between 1 and 40
sum = 0
target = 40
i = 1
while (i <= target):
    if (i % 2 == 0):
        sum += i
    i += 1
print(f"result is: {sum}")
# Out:
# result is: 420

# %%
# find the sum of digits of a givin number
num = input("enter a number:")
sum = 0
i = 0
# way one:" solve this problem via for"
"""
for n in num:
    sum += int(n)
print(f"sum of numbers via for:{sum}")
"""

while True:
    try:
        sum += int(num[i])
        i += 1
    except IndexError:
        break

print(f"sum all digits of number {num}: {sum}")
# Out:
# sum all digits of number 4321: 10

# %%
# reverse the digits of a givin number
num = input("enter a number:")
new_number = ""
i = 1

# way one:" solve this problem via for"
"""
for n in num:
    sum += int(n)
print(f"sum of numbers via for:{sum}")
"""
# way two
while True:
    try:
        new_number += num[-i]
        i += 1
    except IndexError:
        break

print(f"reverse the digits {num}: {new_number}")
# Out:
# reverse the digits 654321: 123456
