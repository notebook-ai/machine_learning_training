# %%
"""
List:
*. Ordered, mutable collections of itmes
1. append(x)
2. extend(iterable)
3. insert(i, x)
4. remove(x)
5. pop([i])
6. clear()
7. index()
8. count(x)
9. sort
10. reverse
11. copy()

"""
