# %%
# _____operatrors_____
"""
+ (Addition): x + y
- (subtraction): x - y
* (Multiplication): x * y
/ (division): x / y
% (Modulus): x % y
** (Exponentiation): x ** y
// (floor division): x // y
"""
x = 6
y =  2
addition = x + y
subtraction = x - y
multiplication = x * y
division = x / y
modulus = x % y
exponentiation = x ** y
floor_division = x // y

print("result addition: " , addition)
print("result subtraction: " , subtraction)
print("result multiplication: " , multiplication)
print("result division: " , division)
print("result modulus: " , modulus)
print("result exponentiation: " , exponentiation)
print("result floor_division: " , floor_division)
# Out:
# result addition:  8
# result subtraction:  4
# result multiplication:  12
# result division:  3.0
# result modulus:  0
# result exponentiation:  36
# result floor_division:  3

# %%
name = "john"
family = "bovary"
fullname = name+ " " + family
print(fullname)
# Out:
# john bovary

# %%
"""
All operations start from left to right:

1. Parantheses
2. Exponentiation
3. Multiplication, division, floor division, modulus
4. Addition, subtraction
"""
# Out:
# '\nAll operations start from left to right:\n\n1. Parantheses\n2. Exponentiation\n3. Multiplication, division, floor division, modulus\n4. Addition, subtraction\n\n'

# %%
ex = 2 ** 3 ** 1 # (2 ** (3 ** 1))
ex
# Out:
# 8

# %%
print('hi')
print     (    'hi'    )
# Out:
# hi
# hi

# %%
for i in range(1,4):
    print(i)
# Out:
# 1
# 2
# 3

# %%
#Assignment operators:
"""
=
+=
-=
*=
/=
%=
**=
//=

"""
num = 5
num += 1
print(num)
# Out:
# 6

# %%
a = 5
b = 6
print(a == b)

# other way
if (a==b):
    print("a, b values are Equal")
else:
    print("a, b values are NOT Equal")
# Out:
# False
# a, b values are NOT Equal

# %%
print(a!=b)
# other way
if (a!=b):
    print("a, b values are NOT Equal")
else:
    print("a, b values are Equal")
# Out:
# True
# a, b values are NOT Equal

# %%
#Binary Representation
var_one = 0.1
var_two = 0.2
result_vars = var_one + var_two
print(result_vars)

print(0.1+0.2 == 0.3)
print(0.1+0.2 != 0.3)
# Out:
# 0.30000000000000004
# False
# True

# %%
# scientific notation
large_float = 1.5e6 # 1.5 * 10^6
small_float = 2.5e-4 # 2.5 * 10^-4

# %%
 print('i'm john')
# Out:
#   Cell In[24], line 1
#     print('i'm john')
#                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('i\'m john') # \ is slash
print("i'm john")
# Out:
# i'm john
# i'm john

# %%
print("Hello\tWorld") # t is tab
print("Hello\nWorld") # n is new line
# Out:
# Hello	World
# Hello
# World

# %%
age = input("please enter you'r age")
print(age)
# Out:
# 5

# %%
type(age)
# Out:
# str

# %%
"""
F-string

[] is Brocket or Square bracket
{} is curly brace or curly bracket
"""
firstname = "john"
age = 30
msg = f"My name is {firstname} and i'm {age} years old" 
print(msg)
# Out:
# My name is john and i'm 30 years old
