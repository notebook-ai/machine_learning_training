# %%
# _____operatrors_____
"""
+ (Addition): x + y
- (subtraction): x - y
* (Multiplication): x * y
/ (division): x / y
% (Modulus): x % y
** (Exponentiation): x ** y
// (floor division): x // y
"""
