# %%
# iterating over a list
fruits = ['apple', 'banana', 'orange']
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# orange

# %%
# Iterating over a string
text = "Hello"

for letter in text:
    print(letter)
# Out:
# H
# e
# l
# l
# o
