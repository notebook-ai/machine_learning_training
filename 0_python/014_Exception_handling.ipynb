# %%
# Type of Errors
"""
1. Syntax Error

if True
print("say somting")
"""
 
"""
2. Exception (Runtime Errors)

2.1: ZeroDivisionError
result = 10 / 0 

2.2: Index Error
lst_nums = [1,2,3]
print|(lst_nums[5])

2.3: keyError
my_dict = {'name' : 'bob'}
print(my_dict["age"])

2.4: Type Error
res = "text" + 10

2.5: Attribute Error
lst = [1,2,3]
lst.appended(5)

2.6: Import Error

2.7: FileNotFoundError

with open("readme.txt", 'r') as file:
    content = file.read()
2.8: Value Error
num = int("something")

"""

# %%
import numpy as np

# %%
#with open("notes/note_03_OOP.txt", 'r') as file:
with open("../README.md", 'r') as file:
    content = file.read()
print(content)
# Out:
# # machine_learning_training
# machine learning

# %%
try:
    file = open("../README.md", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found!")
finally:
    file.close()
# Out:
# # machine_learning_training
# machine learning

# %%
a = 8
b = 1
try:
    result = a / b
    print(result)
except ZeroDivisionError:
    print("you can't any number divided by zero")
# Out:
# 8.0

# %%
try:
    x = int(input("enter a number(x): "))
    y = int(input("enter a number(y): "))
    result = x / y
except ValueError:
    print("that's not a valid number")
except ZeroDivisionError:
    print("you can't any number divided by zero")
else:
    print(f"The result is {result:.2f}")
# Out:
# The result is 2.000

# %%
try:
    x = int(input("enter a number(x): "))
    y = int(input("enter a number(y): "))
    result = x / y
except ValueError:
    print("that's not a valid number")
except ZeroDivisionError:
    print("you can't any number divided by zero")
else:
    if isinstance(result, float):
        print(f"The result is: {result:.2f}")
    else:
        print(f"The result is::: {result}")
# Out:
# The result is: 3.00

# %%
try:
    x = int(input("enter a number(x): "))
    y = int(input("enter a number(y): "))
    result = x / y
except Exception as e:
    print(f"An error occurred: {e}")
else:
    print(f"The result is: {result}")
# Out:
# An error occurred: invalid literal for int() with base 10: 'd'

# %%
# Nested try-except
try:
    try:
        x = int(input("enter a number(x): "))
        y = int(input("enter a number(y): "))
        result = x / y
        print(f"The result is: {result:.2f}")
    except ValueError:
        print("that's not a valid number")
except ZeroDivisionError:
    print("you can't any number divided by zero")
# Out:
# that's not a valid number

# %%
file = None
try:
    file = open("../README.md", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("file not found")
finally:
    if file:
        file.close()
    print("file close")
# Out:
# # machine_learning_training
# machine learning
#
# file close
