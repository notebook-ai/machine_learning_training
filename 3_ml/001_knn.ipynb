# %%
training_acc = []
test_acc = []

neighbors_setting = range(1,20)

for n_neighbors in neighbors_setting:
    knn = KNeighborsClassifier(n_neighbors = n_neighbors)
    knn.fit(X_train, Y_train.ravel())
    training_acc.append(knn.score(X_train, Y_train ))
    test_acc.append(knn.score(X_test, Y_test))

plt.figure(figsize=(15,5), dpi = 200)
plt.plot(neighbors_setting, training_acc, label = 'Acc of training')
plt.plot(neighbors_setting, test_acc, label = 'Acc of test Set')
plt.ylabel("Acc")
plt.xlabel("Number of Neighbors")
plt.legend()
plt.annotate("Best K", xy=(4,0.7), xytext = (8.2, 0.8), arrowprops =dict(facecolor='black', shrink=0.5), fontsize=20)
plt.axvline(x=4, color='b', linestyle= 'dotted')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 neighbors_setting = range(1,20)
#       6 for n_neighbors in neighbors_setting:
# ----> 7     knn = KNeighborsClassifier(n_neighbors = n_neighbors)
#       8     knn.fit(X_train, Y_train.ravel())
#       9     training_acc.append(knn.score(X_train, Y_train ))
#
# NameError: name 'KNeighborsClassifier' is not defined
